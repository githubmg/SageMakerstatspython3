# %%
! ./predict.sh test.csv
# Out:
# *   Trying 127.0.0.1...
# * TCP_NODELAY set
# * Connected to localhost (127.0.0.1) port 8080 (#0)
# > POST /invocations HTTP/1.1
# > Host: localhost:8080
# > User-Agent: curl/7.60.0
# > Accept: */*
# > Content-Type: text/csv
# > Content-Length: 207670
# > Expect: 100-continue
# >
# < HTTP/1.1 100 Continue
# * We are completely uploaded and fine
# < HTTP/1.1 200 OK
# < Server: nginx/1.10.3 (Ubuntu)
# < Date: Mon, 08 Apr 2019 14:00:29 GMT
# < Content-Type: text/csv; charset=utf-8
# < Content-Length: 284017
# < Connection: keep-alive
# <
# 0.1132681406730013
# 0.07929910698279866
# 0.06768094107442983
# 0.07929910698279866
# 0.1289466183084824
# 0.04901697205745198
# 0.0806538396967372
# 0.0753356698083713
# 0.107123908231686
# 0.07815795220501193
# 0.08534729984793885
# 0.11113706589299929
# 0.07817981346688661
# 0.09118231784968665
# 0.07245874080401164
# 0.107123908231686
# 0.09998530179350959
# 0.08782380648056731
# 0.18071765699376452
# 0.13767613023405756
# 0.1091824349513869
# ...
